# %%
import spacy
import glob
import os
import json
import pandas as pd
from spacy import displacy

# %%
def add(self, data):
        # Add something to the component's data
        self.data.append(data)

def to_disk(self, path, exclude=tuple()):    # This will receive the directory path + /my_component   
    data_path = path / "data.json"        
    with data_path.open("w", encoding="utf8") as f:            
        f.write(json.dumps(self.data))

def from_disk(self, path, exclude=tuple()):        # This will receive the directory path + /my_component       
    data_path = path / "data.json"        
    with data_path.open("r", encoding="utf8") as f:            
        self.data = json.loads(f)        
    return self

# %%
path = 'test_parsing_no_annotations'    # the path of the folder 

df = pd.DataFrame(columns=["authors", "date_download", "date_modify", "date_publish", "description", "filename", "image_url", "language", "localpath", "source_domain", "text", "title", "title_page", "title_rss", "url"])

for filename in os.listdir(path)[1:]:
    frames = []
    print("Reading in files from folder: " + filename)
    for full_filename in glob.glob(os.path.join(path+"/"+filename, "*.json")):    #iterate through every file
        print("Executing code for ", str(full_filename))
        with open(full_filename, encoding='utf-8', mode='r') as currentFile:
            jo = json.loads(currentFile.read())
            df_tmp = pd.DataFrame({"authors": [jo["authors"]], "date_download": jo["date_download"], "date_modify": jo["date_modify"], "date_publish": jo["date_publish"], "description": jo["description"], "filename": filename, "image_url": jo["image_url"], "language": jo["language"], "localpath": jo["localpath"], "source_domain": jo["source_domain"], "text": jo["text"], "title": jo["title"], "title_page": jo["title_page"], "title_rss": jo["title_rss"], "url": jo["url"]})
            df = pd.concat([df, df_tmp], ignore_index=True, axis = 0)
    #break
# Out:
# Reading in files from folder: 0_CIADirectorMikePompeoMeetingNorthKorea
# Executing code for  test_parsing_no_annotations/0_CIADirectorMikePompeoMeetingNorthKorea\0_L.json
# Executing code for  test_parsing_no_annotations/0_CIADirectorMikePompeoMeetingNorthKorea\0_LL.json
# Executing code for  test_parsing_no_annotations/0_CIADirectorMikePompeoMeetingNorthKorea\0_M.json
# Executing code for  test_parsing_no_annotations/0_CIADirectorMikePompeoMeetingNorthKorea\0_R.json
# Executing code for  test_parsing_no_annotations/0_CIADirectorMikePompeoMeetingNorthKorea\0_RR.json
# Reading in files from folder: 1_ComeyMemo
# Executing code for  test_parsing_no_annotations/1_ComeyMemo\1_L.json
# Executing code for  test_parsing_no_annotations/1_ComeyMemo\1_LL.json
# Executing code for  test_parsing_no_annotations/1_ComeyMemo\1_M.json
# Executing code for  test_parsing_no_annotations/1_ComeyMemo\1_R.json
# Executing code for  test_parsing_no_annotations/1_ComeyMemo\1_RR.json
# Reading in files from folder: 2_NorthKoreaNuclearStopAnnouncement
# Executing code for  test_parsing_no_annotations/2_NorthKoreaNuclearStopAnnouncement\2_L.json
# Executing code for  test_parsing_no_annotations/2_NorthKoreaNuclearStopAnnouncement\2_LL.json
# Executing code for  test_parsing_no_annotations/2_NorthKoreaNuclearStopAnnouncement\2_M.json
# Executing code for  test_parsing_no_annotations/2_NorthKoreaNuclearStopAnnouncement\2_R.json
# Executing code for  test_parsing_no_annotations/2_NorthKoreaNuclearStopAnnouncement\2_RR.json
# Reading in files from folder: 3_DemocratsSueRUTrump
# Executing code for  test_parsing_no_annotations/3_DemocratsSueRUTrump\3_L.json
# Executing code for  test_parsing_no_annotations/3_DemocratsSueRUTrump\3_LL.json
# Executing code for  test_parsing_no_annotations/3_DemocratsSueRUTrump\3_M.json
# Executing code for  test_parsing_no_annotations/3_DemocratsSueRUTrump\3_R.json
# Executing code for  test_parsing_no_annotations/3_DemocratsSueRUTrump\3_RR.json
# Reading in files from folder: 4_TrumpDealIran
# Executing code for  test_parsing_no_annotations/4_TrumpDealIran\4_L.json
# Executing code for  test_parsing_no_annotations/4_TrumpDealIran\4_LL.json
# Executing code for  test_parsing_no_annotations/4_TrumpDealIran\4_M.json
# Executing code for  test_parsing_no_annotations/4_TrumpDealIran\4_R.json
# Executing code for  test_parsing_no_annotations/4_TrumpDealIran\4_RR.json
# Reading in files from folder: 5_TrumpVisitUnitedKingdom
# Executing code for  test_parsing_no_annotations/5_TrumpVisitUnitedKingdom\5_L.json
# Executing code for  test_parsing_no_annotations/5_TrumpVisitUnitedKingdom\5_LL.json
# Executing code for  test_parsing_no_annotations/5_TrumpVisitUnitedKingdom\5_M.json
# Executing code for  test_parsing_no_annotations/5_TrumpVisitUnitedKingdom\5_R.json
# Executing code for  test_parsing_no_annotations/5_TrumpVisitUnitedKingdom\5_RR.json
# Reading in files from folder: 6_Asylum-SeekingMigrantCaravan
# Executing code for  test_parsing_no_annotations/6_Asylum-SeekingMigrantCaravan\6_L.json
# Executing code for  test_parsing_no_annotations/6_Asylum-SeekingMigrantCaravan\6_LL.json
# Executing code for  test_parsing_no_annotations/6_Asylum-SeekingMigrantCaravan\6_M.json
# Executing code for  test_parsing_no_annotations/6_Asylum-SeekingMigrantCaravan\6_R.json
# Executing code for  test_parsing_no_annotations/6_Asylum-SeekingMigrantCaravan\6_RR.json
# Reading in files from folder: 7_TrumpDelaysTariff
# Executing code for  test_parsing_no_annotations/7_TrumpDelaysTariff\7_L.json
# Executing code for  test_parsing_no_annotations/7_TrumpDelaysTariff\7_LL.json
# Executing code for  test_parsing_no_annotations/7_TrumpDelaysTariff\7_M.json
# Executing code for  test_parsing_no_annotations/7_TrumpDelaysTariff\7_R.json
# Executing code for  test_parsing_no_annotations/7_TrumpDelaysTariff\7_RR.json
# Reading in files from folder: 8_MuellerQuestionsTrump
# Executing code for  test_parsing_no_annotations/8_MuellerQuestionsTrump\8_L.json
# Executing code for  test_parsing_no_annotations/8_MuellerQuestionsTrump\8_LL.json
# Executing code for  test_parsing_no_annotations/8_MuellerQuestionsTrump\8_M.json
# Executing code for  test_parsing_no_annotations/8_MuellerQuestionsTrump\8_R.json
# Executing code for  test_parsing_no_annotations/8_MuellerQuestionsTrump\8_RR.json
# Reading in files from folder: 9_Iranfiles
# Executing code for  test_parsing_no_annotations/9_Iranfiles\9_L.json
# Executing code for  test_parsing_no_annotations/9_Iranfiles\9_LL.json
# Executing code for  test_parsing_no_annotations/9_Iranfiles\9_M.json
# Executing code for  test_parsing_no_annotations/9_Iranfiles\9_R.json
# Executing code for  test_parsing_no_annotations/9_Iranfiles\9_RR.json

# %%
df.head()
# Out:
#   authors date_download date_modify date_publish  \
# 0      []          None        None         None
# 1      []          None        None         None
# 2      []          None        None         None
# 3      []          None        None         None
# 4      []          None        None         None
#
#                                          description  \
# 0
# 1  Donald Trump is planning to meet with the Nort...
# 2  President Donald Trump says conversations betw...
# 3
# 4
#
#                                    filename image_url language localpath  \
# 0  0_CIADirectorMikePompeoMeetingNorthKorea      None       en      None
# 1  0_CIADirectorMikePompeoMeetingNorthKorea      None       en      None
# 2  0_CIADirectorMikePompeoMeetingNorthKorea      None       en      None
# 3  0_CIADirectorMikePompeoMeetingNorthKorea      None       en      None
# 4  0_CIADirectorMikePompeoMeetingNorthKorea      None       en      None
#
#   source_domain                                               text  \
# 0           0_L  WEST PALM BEACH, Fla. — President Trump dispat...
# 1          0_LL  Central Intelligence Agency Director Mike Pomp...
# 2           0_M  PALM BEACH, Fla. — President Trump began meeti...
# 3           0_R  The Washington Post reports the CIA director m...
# 4          0_RR  CIA Director Mike Pompeo, now President Donald...
#
#                                                title title_page title_rss  \
# 0                                                          None      None
# 1  CIA Director Mike Pompeo secretly met with Nor...       None      None
# 2  Mike Pompeo, Trump's secretary of State pick, ...       None      None
# 3           Report: Mike Pompeo met with Kim Jong Un       None      None
# 4  Report: Mike Pompeo secretly met with Kim Jong...       None      None
#
#     url
# 0  None
# 1  None
# 2  None
# 3  None
# 4  None

# %%
from tqdm import tqdm

# %%
nlp = spacy.load('en_core_web_sm')
docs = []

for element in tqdm(df["text"]):
    doc = nlp(element)
    docs.append(doc)

df["doc"] = docs
# Out:
# 100%|██████████| 50/50 [00:07<00:00,  6.39it/s]

# %%
displacy.render(list(docs[0].sents)[1:2])   #display the first sentence of the first article
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="05ba8408c46a441fbb1a9c3556e92234-0" class="displacy" width="8275" height="837.0" direction="ltr" style="max-width: none; height: 837.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">President</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">Trump</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">dispatched</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">C.I.A.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="925">director</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">Mike</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="1275">Pompeo</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="1450">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="1625">North</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="1800">Korea</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="1975">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">meet</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="2325">with</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="2500">its</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2500">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="2675">leader,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2675">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="2850">Kim</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="3025">Jong-</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3025">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="3200">un,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="3375">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3375">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="3550">recent</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3550">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="3725">weeks</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3725">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="3900">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3900">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="4075">lay</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4075">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="4250">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4250">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="4425">groundwork</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4425">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="4600">for</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4600">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="4775">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4775">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="4950">summit</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4950">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="5125">meeting</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="5125">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="5300">between</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="cur

# %%
df.head(30)
# Out:
#    authors date_download date_modify date_publish  \
# 0       []          None        None         None
# 1       []          None        None         None
# 2       []          None        None         None
# 3       []          None        None         None
# 4       []          None        None         None
# 5       []          None        None         None
# 6       []          None        None         None
# 7       []          None        None         None
# 8       []          None        None         None
# 9       []          None        None         None
# 10      []          None        None         None
# 11      []          None        None         None
# 12      []          None        None         None
# 13      []          None        None         None
# 14      []          None        None         None
# 15      []          None        None         None
# 16      []          None        None         None
# 17      []          None        None         None
# 18      []          None        None         None
# 19      []          None        None         None
# 20      []          None        None         None
# 21      []          None        None         None
# 22      []          None        None         None
# 23      []          None        None         None
# 24      []          None        None         None
# 25      []          None        None         None
# 26      []          None        None         None
# 27      []          None        None         None
# 28      []          None        None         None
# 29      []          None        None         None
#
#                                           description  \
# 0
# 1   Donald Trump is planning to meet with the Nort...
# 2   President Donald Trump says conversations betw...
# 3
# 4
# 5
# 6
# 7
# 8   Comey claims FBI does not leak in redacted mem...
# 9
# 10  A photograph released by North Korea's state n...
# 11
# 12  North Korea's Kim suspends nuclear, missile te...
# 13  North Korean dictator Kim Jong Un's surprise a...
# 14
# 15  Tom Perez, the chairman of the Democratic Part...
# 16  The party alleged that top officials in Trump'...
# 17  A major lawsuit from the Democratic National C...
# 18     DNC files lawsuit over election interference.
# 19
# 20  President Trump and Melania Trump, the first l...
# 21  It looks like Trump took his fellow Republican...
# 22
# 23
# 24
# 25
# 26  The US President will 'definitely be coming to...
# 27
# 28  Trump, May reaffirm 'special relationship' in ...
# 29
#
#                                     filename image_url language localpath  \
# 0   0_CIADirectorMikePompeoMeetingNorthKorea      None       en      None
# 1   0_CIADirectorMikePompeoMeetingNorthKorea      None       en      None
# 2   0_CIADirectorMikePompeoMeetingNorthKorea      None       en      None
# 3   0_CIADirectorMikePompeoMeetingNorthKorea      None       en      None
# 4   0_CIADirectorMikePompeoMeetingNorthKorea      None       en      None
# 5                                1_ComeyMemo      None       en      None
# 6                                1_ComeyMemo      None       en      None
# 7                                1_ComeyMemo      None       en      None
# 8                                1_ComeyMemo      None       en      None
# 9                                1_ComeyMemo      None       en      None
# 10       2_NorthKoreaNuclearStopAnnouncement      None       en      None
# 11       2_NorthKoreaNuclearStopAnnouncement      None       en      None
# 12       2_NorthKoreaNuclearStopAnnouncement      None       en      None
# 13       2_NorthKoreaNuclearStopAnnouncement      None       en      None
# 14       2_NorthKoreaNuclearStopAnnouncement      None       en      None
# 15                     3_DemocratsSueRUTrump      None       en      None
# 16                     3_DemocratsSueRUTrump      None       en      None
# 17                     3_DemocratsSueRUTrump      None       en      None
# 18                     3_DemocratsSueRUTrump      None       en      None
# 19                     3_DemocratsSueRUTrump      None       en      None
# 20                           4_TrumpDealIran      None       en      None
# 21                           4_TrumpDealIran      None       en      None
# 22                           4_TrumpDealIran      None       en      None
# 23                           4_TrumpDealIran      None       en      None
# 24                           4_TrumpDealIran      None       en      None
# 25                 5_TrumpVisitUnitedKingdom      None       en      None
# 26                 5_TrumpVisitUnitedKingdom      None       en      None
# 27                 5_TrumpVisitUnitedKingdom      None       en      None
# 28                 5_TrumpVisitUnitedKingdom      None       en      None
# 29                 5_TrumpVisitUnitedKingdom      None       en      None
#
#    source_domain                                               text  \
# 0            0_L  WEST PALM BEACH, Fla. — President Trump dispat...
# 1           0_LL  Central Intelligence Agency Director Mike Pomp...
# 2            0_M  PALM BEACH, Fla. — President Trump began meeti...
# 3            0_R  The Washington Post reports the CIA director m...
# 4           0_RR  CIA Director Mike Pompeo, now President Donald...
# 5            1_L  WASHINGTON — President Trump spoke in intimate...
# 6           1_LL  "He said he was grateful for the conversation,...
# 7            1_M  WASHINGTON — A series of explosive memos prepa...
# 8            1_R  President Trump late Thursday tweeted that the...
# 9           1_RR  President Donald Trump commented on the public...
# 10           2_L  SEOUL, South Korea — North Korea's leader, Kim...
# 11          2_LL  Pyongyang also said it plans to close down a f...
# 12           2_M  North Korean leader Kim Jong Un announced he w...
# 13           2_R  Kim's announcement Saturday (local time) may s...
# 14          2_RR  Various reports in American and South Korean s...
# 15           3_L  The Democratic National Committee opened a sur...
# 16          3_LL  WASHINGTON (Reuters) - The Democratic Party su...
# 17           3_M  WASHINGTON — The Democratic National Committee...
# 18           3_R  The Democratic Party on Friday filed a multimi...
# 19          3_RR  The Democratic National Committee is suing the...
# 20           4_L  WASHINGTON — President Trump signaled on Tuesd...
# 21          4_LL  French President Emmanuel Macron tried to pers...
# 22           4_M  WASHINGTON — President Trump vowed Tuesday to ...
# 23           4_R  President Trump warned Iran's leaders Tuesday ...
# 24          4_RR  Iranian President Hassan Rouhani warns Saudi A...
# 25           5_L  President Barack Obama and his wife, Michelle ...
# 26          5_LL  Donald Trump will visit London in July despite...
# 27           5_M  WASHINGTON — President Trump will travel to th...
# 28           5_R  President Trump will travel to the United King...
# 29          5_RR  The President of the United States Donald Trum...
#
#                                                 title title_page title_rss  \
# 0                                                           None      None
# 1   CIA Director Mike Pompeo secretly met with Nor...       None      None
# 2   Mike Pompeo, Trump's secretary of State pick, ...       None      None
# 3            Report: Mike Pompeo met with Kim Jong Un       None      None
# 4   Report: Mike Pompeo secretly met with Kim Jong...       None      None
# 5                                                           None      None
# 6     Here are the redacted copies of the Comey Memos       None      None
# 7   Comey memos released to Congress, track his te...       None      None
# 8   Trump tweets that Comey memos 'clearly' show n...       None      None
# 9   Donald Trump: Comey memos show 'he leaked clas...       None      None
# 10  ‘We No Longer Need' Nuclear or Missile Tests, ...       None      None
# 11  North Korea suspends nuclear and missile tests...       None      None
# 12  North Korea to suspend nuclear missile tests a...       None      None
# 13  Beware of North Korea's nuclear and missile pl...       None      None
# 14  Reports: North Korean state media announced nu...       None      None
# 15  Democratic Party alleges Trump-Russia conspira...       None      None
# 16  Democrats sue Russia and Trump campaign, alleg...       None      None
# 17  Democratic Party sues Russia, the Trump campai...       None      None
# 18  Democratic Party files suit alleging conspirac...       None      None
# 19  DESPERATION: DNC files multi-million dollar la...       None      None
# 20  Trump signals openness to a ‘new deal' to cons...       None      None
# 21  Trump hates the Iran deal and may kill it – ev...       None      None
# 22  Trump, Emmanuel Macron seek common ground on I...       None      None
# 23  Trump warns Iran on nuclear program as Macron ...       None      None
# 24  Donald Trump warns Iran against restarting nuc...       None      None
# 25  President Trump is coming to Britain. Here's w...       None      None
# 26  Donald Trump's UK visit on 13 July confirmed a...       None      None
# 27  Trump will visit UK in July, ending more than ...       None      None
# 28  Trump to visit United Kingdom in July, meet wi...       None      None
# 29    President Trump to visit United Kingdom in July       None      None
#
#      url                                                doc
# 0   None  (WEST, PALM, BEACH, ,, Fla., —, President, Tru...
# 1   None  (Central, Intelligence, Agency, Director, Mike...
# 2   None  (PALM, BEACH, ,, Fla., —, President, Trump, be...
# 3   None  (The, Washington, Post, reports, the, CIA, dir...
# 4   None  (CIA, Director, Mike, Pompeo, ,, now, Presiden...
# 5   None  (WASHINGTON, —, President, Trump, spoke, in, i...
# 6   None  (", He, said, he, was, grateful, for, the, con...
# 7   None  (WASHINGTON, —, A, series, of, explosive, memo...
# 8   None  (President, Trump, late, Thursday, tweeted, th...
# 9   None  (President, Donald, Trump, commented, on, the,...
# 10  None  (SEOUL, ,, South, Korea, —, North, Korea, 's, ...
# 11  None  (Pyongyang, also, said, it, plans, to, close, ...
# 12  None  (North, Korean, leader, Kim, Jong, Un, announc...
# 13  None  (Kim, 's, announcement, Saturday, (, local, ti...
# 14  None  (Various, reports, in, American, and, South, K...
# 15  None  (The, Democratic, National, Committee, opened,...
# 16  None  (WASHINGTON, (, Reuters, ), -, The, Democratic...
# 17  None  (WASHINGTON, —, The, Democratic, National, Com...
# 18  None  (The, Democratic, Party, on, Friday, filed, a,...
# 19  None  (The, Democratic, National, Committee, is, sui...
# 20  None  (WASHINGTON, —, President, Trump, signaled, on...
# 21  None  (French, President, Emmanuel, Macron, tried, t...
# 22  None  (WASHINGTON, —, President, Trump, vowed, Tuesd...
# 23  None  (President, Trump, warned, Iran, 's, leaders, ...
# 24  None  (Iranian, President, Hassan, Rouhani, warns, S...
# 25  None  (President, Barack, Obama, and, his, wife, ,, ...
# 26  None  (Donald, Trump, will, visit, London, in, July,...
# 27  None  (WASHINGTON, —, President, Trump, will, travel...
# 28  None  (President, Trump, will, travel, to, the, Unit...
# 29  None  (The, President, of, the, United, States, Dona...

# %%
#checks if the token ids are concurrent within the sentence, i.e. 3-4-5-6, not 3-4-6-7
def checkContinuous(nums):
   if len(nums) < 1:
      return False
   min_val = min(nums)
   max_val = max(nums)
   if max_val - min_val + 1 == len(nums):
      for i in range(len(nums)):
         if nums[i] < 0:
            j = -nums[i] - min_val
         else:
            j = nums[i] - min_val
            if nums[j] > 0:
               nums[j] = -nums[j]
            else:
               return False
      return True
   return False

# %%
#checks if a token has children it refers to
def checkSingleton(token):
    counter = 0
    for c in token.children:
        counter = counter + 1
    if counter == 0:
        return True
    else:
        return False

# %%
import ujson

# %%
#read other csvs for annotations
path_annotations = '2019_annot/'    # the path of the folder 

df_annotations = pd.DataFrame()

for full_filename in glob.glob(os.path.join(path_annotations, "*.csv")):    #iterate through every file
    print("Executing code for ", str(full_filename))
    with open(full_filename, encoding='utf-8', mode='r') as currentFile:
        df_tmp = pd.read_csv(currentFile)
        df_annotations = pd.concat([df_annotations, df_tmp], ignore_index=True, axis = 0)
    

df_annotations.head(3000)
# Out:
# Executing code for  2019_annot\0_CIADirectorMikePompeoMeetingNorthKorea.csv
# Executing code for  2019_annot\1_ComeyMemo.csv
# Executing code for  2019_annot\2_NorthKoreaNuclearStopAnnouncement.csv
# Executing code for  2019_annot\3_DemocratsSueRUTrump.csv
# Executing code for  2019_annot\4_TrumpDealIran.csv
# Executing code for  2019_annot\5_TrumpVisitUnitedKingdom.csv
# Executing code for  2019_annot\6_Asylum-SeekingMigrantCaravan.csv
# Executing code for  2019_annot\7_TrumpDelaysTariff.csv
# Executing code for  2019_annot\8_MuellerQuestionsTrump.csv
# Executing code for  2019_annot\9_Iranfiles.csv
#      Color Document name                   Code  Weight score  \
# 0        ●           0_R                    PRK             0
# 1        ●           0_R                    USA             0
# 2        ●           0_R            PRK\Jong Un             0
# 3        ●           0_R                    USA             0
# 4        ●           0_R            PRK\Jong Un             0
# ...    ...           ...                    ...           ...
# 2995     ●          3_LL                    USA             0
# 2996     ●          3_LL  USA\Republicans\Trump             0
# 2997     ●          3_LL        USA\Republicans             0
# 2998     ●          3_LL  USA\Republicans\Trump             0
# 2999     ●          3_LL          USA\Democrats             0
#
#                               Segment Author       Creation date Comment  \
# 0                         Kim Jong Un  maxku  19-Apr-18 17:15:58     NaN
# 1                        CIA director  maxku  19-Apr-18 17:18:30     NaN
# 2                 North Korean leader  maxku  19-Apr-18 17:18:38     NaN
# 3     chief White House correspondent  maxku  19-Apr-18 17:18:48     NaN
# 4               North Korean dictator  maxku  19-Apr-18 17:19:18     NaN
# ...                               ...    ...                 ...     ...
# 2995                          the FBI  maxku      18-05-18 07:51     NaN
# 2996                            Trump  maxku      18-05-18 07:51     NaN
# 2997                     a Republican  maxku      18-05-18 07:51     NaN
# 2998                            Trump  maxku      18-05-18 07:52     NaN
# 2999                          the DNC  maxku      18-05-18 07:52     NaN
#
#       Document group  Area  Coverage %  Beginning  End
# 0                NaN    11        0.30          1    1
# 1                NaN    12        0.32          2    2
# 2                NaN    19        0.51          2    2
# 3                NaN    31        0.83          2    2
# 4                NaN    21        0.56          3    3
# ...              ...   ...         ...        ...  ...
# 2995             NaN     7        0.14          8    8
# 2996             NaN     5        0.10          8    8
# 2997             NaN    12        0.24          8    8
# 2998             NaN     5        0.10          9    9
# 2999             NaN     7        0.14          9    9
#
# [3000 rows x 13 columns]

# %%
def paragraphs(document):
    start = 0
    for token in document:
        if token.is_space and token.text.count("\n") > 1:
            yield document[start:token.i]
            start = token.i
    yield document[start:]

# %%
df_preparation_list = []

print("Going to process " + str(len(df)) + " dataframe rows...")
for i, row in tqdm(df.iterrows()):
    doc = row["doc"]
    filename = row["filename"]
    description = row["description"]
    doc_id = row["source_domain"].split("_")[0]
    pol_direction = row["source_domain"].split("_")[1]
    doc_id_full = row["source_domain"]
    doc_unique_id = doc_id_full+"_"+str(i)
    
    #compare whole segment with tokens
    #iterate over tokens and segment tokens seperately
    #if they are close enough (+-1 in position) accept it (maybe print warning)
    #take the accepted token and determine the head
    #token ids should match the exact appearences in the text of the segment tokens
    #take care of abbreviations

    for j, sentence in enumerate(doc.sents):
        for anno_i, row_anno in df_annotations.iterrows():
            if doc_id_full == row_anno["Document name"]:
                if row_anno["Segment"] in sentence.text:

                    fitting_tokens = []
                    fitting_token_str = []
                    seg_token = 0
                    iterations_without_token_match = 0
                
                    segment_doc = nlp(row_anno["Segment"])
                    segment_tokenized = []

                    for t in segment_doc:
                        segment_tokenized.append(t)

                    for token in sentence:

                        if len(segment_tokenized) <= seg_token:
                            #add to the list
                            if seg_token >= 1:
                                sent_id = j
                                text = row["text"]
                                code = row_anno["Code"].replace("\\", " ")
                                segment = row_anno["Segment"]
                                score = -1  #not row_anno["Weight score"], not that important (legacy)
                                is_continuous = checkContinuous(tokens_number[:])
                                is_singleton = checkSingleton(token)
                                mention_id = doc_unique_id+"_"+str(sent_id)+"_"+str(tokens_number[0])
                                head_id = token.head.i - sentence.start
                                coref_type = "STRICT"
                                
                                coref_chain = "tbd"
                                mention_type = "tbd"
                                
                                if iterations_without_token_match > 1:
                                    print("Warning: the segment does not match 100%: " + segment)
                                    print("Sentence: " + str(sentence))

                                df_preparation_list.append([coref_chain, code, segment, doc_unique_id, doc_id, pol_direction, is_continuous, is_singleton, text, sentence.text, mention_id, mention_type[:3], mention_type, score, sent_id, fitting_tokens, fitting_token_str, row_anno["Segment"], filename.split("_")[0], coref_type, description, token.head.text, head_id])
                                #break   #only one mention of the same kind per sentence is valid

                            fitting_tokens = []
                            fitting_token_str = []
                            seg_token = 0

                        if token.text == segment_tokenized[seg_token].text:
                            if seg_token == 0:
                                iterations_without_token_match = 0
                            seg_token = seg_token + 1
                            fitting_tokens.append(token.i - sentence.start)     #the id of the token within a sentence
                            fitting_token_str.append(token.text)

                            tokens = []
                            tokens_str = ""
                            tokens_number = []
                            for t in token.head.subtree:
                                tokens.append(t)
                                tokens_str = tokens_str + " " + t.text
                                tokens_number.append(t.i)
                        else:
                            iterations_without_token_match = iterations_without_token_match + 1
                            if iterations_without_token_match > 1:
                                #reset detection if the tokens are spread to far (not exact matching)
                                tokens = []
                                tokens_str = ""
                                tokens_number = []
                                fitting_tokens = []
                                fitting_token_str = []
                                iterations_without_token_match = 0
                                seg_token = 0
                

        #these breaks are just for debugging (faster calc speed)
        #if j>=15:
        #    break
    if i>=10:
        break
#print(df_preparation_list)
# Out:
# Going to process 50 dataframe rows...
# 10it [03:41, 22.11s/it]

# %%
mentions_df = pd.DataFrame(df_preparation_list, columns=["coref_chain", "code", "segment", "doc_id_full","doc_id", "pol_direction", "is_continuous", "is_singleton", "text", "sentence", "mention_id", "mention_type", "mention_full_type", "score", "sent_id", "tokens_number", "fitting_tokens", "tokens_str", "topic_id", "coref_type", "description", "head_str", "head_id"])
print(len(mentions_df))
# Out:
# 9126

# %%
#remove rows from dataframe with duplicate code possibilities (just take the first one)
mentions_df = mentions_df.drop_duplicates(subset=['segment', 'doc_id_full', 'sent_id', 'tokens_str'], keep='first')
print(len(mentions_df))
# Out:
# 1827

# %%
mentions_df.head()
# Out:
#   coref_chain             code          segment doc_id_full doc_id  \
# 0         tbd        USA Trump  President Trump       0_L_0      0
# 1         tbd              USA  C.I.A. director       0_L_0      0
# 2         tbd  USA Mike Pompeo      Mike Pompeo       0_L_0      0
# 3         tbd              PRK      North Korea       0_L_0      0
# 4         tbd      PRK Jong Un      Kim Jong-un       0_L_0      0
#
#   pol_direction  is_continuous  is_singleton  \
# 0             L           True         False
# 1             L           True          True
# 2             L           True         False
# 3             L           True          True
# 4             L           True          True
#
#                                                 text  \
# 0  WEST PALM BEACH, Fla. — President Trump dispat...
# 1  WEST PALM BEACH, Fla. — President Trump dispat...
# 2  WEST PALM BEACH, Fla. — President Trump dispat...
# 3  WEST PALM BEACH, Fla. — President Trump dispat...
# 4  WEST PALM BEACH, Fla. — President Trump dispat...
#
#                                             sentence  ... score sent_id  \
# 0  President Trump dispatched the C.I.A. director...  ...    -1       1
# 1  President Trump dispatched the C.I.A. director...  ...    -1       1
# 2  President Trump dispatched the C.I.A. director...  ...    -1       1
# 3  President Trump dispatched the C.I.A. director...  ...    -1       1
# 4  President Trump dispatched the C.I.A. director...  ...    -1       1
#
#       tokens_number      fitting_tokens       tokens_str topic_id coref_type  \
# 0            [0, 1]  [President, Trump]  President Trump        0     STRICT
# 1            [4, 5]  [C.I.A., director]  C.I.A. director        0     STRICT
# 2            [6, 7]      [Mike, Pompeo]      Mike Pompeo        0     STRICT
# 3           [9, 10]      [North, Korea]      North Korea        0     STRICT
# 4  [17, 18, 19, 20]  [Kim, Jong, -, un]      Kim Jong-un        0     STRICT
#
#   description    head_str head_id
# 0                    said      47
# 1                  Pompeo       7
# 2              dispatched       2
# 3                    meet      12
# 4                    meet      12
#
# [5 rows x 23 columns]

# %%
full_filename = 'aggr_m_conceptcategorization.csv'    # the path of the folder 

concept_df = pd.DataFrame(columns=["Color", "Document name", "Code", "Weight score", "Segment", "Author", "Creation date", "Comment", "Document group", "Area", "Coverage %", "Beginning", "End"])

with open(full_filename, encoding='utf-8', mode='r') as currentFile:
    concept_df = pd.read_csv(currentFile)
    
print(len(concept_df))
# Out:
# 174

# %%
concept_df.head()
# Out:
#    topic_id            Code     type comments
# 0         0       USA\Trump    ACTOR      NaN
# 1         0             USA  COUNTRY      NaN
# 2         0             PRK  COUNTRY      NaN
# 3         0  PRK USA Summit    EVENT      NaN
# 4         0         JPN\Abe    ACTOR      NaN

# %%
mentions_df.code = mentions_df.code.astype(str)
mentions_df.doc_id = mentions_df.doc_id.astype(int)
concept_df.topic_id = concept_df.topic_id.astype(int)
concept_df.Code = concept_df.Code.astype(str)
df_final = pd.merge(mentions_df, concept_df, how = "left", left_on = ["doc_id", "code"], right_on = ["topic_id", "Code"])
print(len(df_final))

#clean the data, some codes are null / do not have a type
df_final = df_final.drop("comments", axis = 1)
df_final = df_final.dropna(axis=0)
print(len(df_final))
# Out:
# 1827
# 735

# %%
df_final.head()
# Out:
#   coref_chain            code                  segment doc_id_full  doc_id  \
# 1         tbd             USA          C.I.A. director       0_L_0       0
# 3         tbd             PRK              North Korea       0_L_0       0
# 7         tbd             USA                   C.I.A.       0_L_0       0
# 8         tbd  PRK USA Summit           summit meeting       0_L_0       0
# 9         tbd     Trip to PRK  to meet with its leader       0_L_0       0
#
#   pol_direction  is_continuous  is_singleton  \
# 1             L           True          True
# 3             L           True          True
# 7             L           True         False
# 8             L           True         False
# 9             L           True          True
#
#                                                 text  \
# 1  WEST PALM BEACH, Fla. — President Trump dispat...
# 3  WEST PALM BEACH, Fla. — President Trump dispat...
# 7  WEST PALM BEACH, Fla. — President Trump dispat...
# 8  WEST PALM BEACH, Fla. — President Trump dispat...
# 9  WEST PALM BEACH, Fla. — President Trump dispat...
#
#                                             sentence  ...  \
# 1  President Trump dispatched the C.I.A. director...  ...
# 3  President Trump dispatched the C.I.A. director...  ...
# 7  President Trump dispatched the C.I.A. director...  ...
# 8  President Trump dispatched the C.I.A. director...  ...
# 9  President Trump dispatched the C.I.A. director...  ...
#
#                   fitting_tokens               tokens_str topic_id_x  \
# 1             [C.I.A., director]          C.I.A. director          0
# 3                 [North, Korea]              North Korea          0
# 7                       [C.I.A.]                   C.I.A.          0
# 8              [summit, meeting]           summit meeting          0
# 9  [to, meet, with, its, leader]  to meet with its leader          0
#
#    coref_type  description    head_str head_id topic_id_y            Code  \
# 1      STRICT                   Pompeo       7        0.0             USA
# 3      STRICT                     meet      12        0.0             PRK
# 7      STRICT               dispatched       2        0.0             USA
# 8      STRICT                  meeting      32        0.0  PRK USA Summit
# 9      STRICT                   leader      15        0.0     Trip to PRK
#
#       type
# 1  COUNTRY
# 3  COUNTRY
# 7  COUNTRY
# 8    EVENT
# 9   ACTION
#
# [5 rows x 26 columns]

# %%
coref_id = 1

for i, row in df_final.iterrows():
    mention_full_type = row["type"]
    mention_type = mention_full_type.replace("-","")
    coref_id = coref_id + 1
    coref_chain = mention_type + str(coref_id).zfill(5)
    df_final.at[i, "coref_chain"] = coref_chain
    df_final.at[i, "mention_type"] = mention_type
    df_final.at[i, "mention_full_type"] = mention_full_type

    #How to determine:
    #Coref_type, score, numbers of coref_chain ?
    #topic_id equals doc_id ?

df_final.rename(columns={"topic_id_x": "topic_id"}, inplace = True)
#drop unwanted columns for the output
df_final = df_final.drop(["segment", "Code", "text", "sentence", "fitting_tokens", "topic_id_y", "head_str", "type", "head_id", "description"], axis = 1)

df_final.rename(columns={"code": "description"}, inplace = True)

# %%
df_final.reset_index(drop=True,inplace=True)

with open(f'./mentions_df.json', 'w', encoding='utf-8') as f:
    f.write(ujson.dumps(df_final.to_dict('index'), indent=4, ensure_ascii=False, escape_forward_slashes=False))

# %%
df_final.head()
# Out:
#     coref_chain     description doc_id_full  doc_id pol_direction  \
# 0  COUNTRY00002             USA       0_L_0       0             L
# 1  COUNTRY00003             PRK       0_L_0       0             L
# 2  COUNTRY00004             USA       0_L_0       0             L
# 3    EVENT00005  PRK USA Summit       0_L_0       0             L
# 4   ACTION00006     Trip to PRK       0_L_0       0             L
#
#    is_continuous  is_singleton  mention_id mention_type mention_full_type  \
# 0           True          True   0_L_0_1_6      COUNTRY           COUNTRY
# 1           True          True  0_L_0_1_14      COUNTRY           COUNTRY
# 2           True         False   0_L_0_1_9      COUNTRY           COUNTRY
# 3           True         False  0_L_0_1_35        EVENT             EVENT
# 4           True          True  0_L_0_1_19       ACTION            ACTION
#
#    score  sent_id         tokens_number               tokens_str topic_id  \
# 0     -1        1                [4, 5]          C.I.A. director        0
# 1     -1        1               [9, 10]              North Korea        0
# 2     -1        1                   [4]                   C.I.A.        0
# 3     -1        1              [31, 32]           summit meeting        0
# 4     -1        1  [11, 12, 13, 14, 15]  to meet with its leader        0
#
#   coref_type
# 0     STRICT
# 1     STRICT
# 2     STRICT
# 3     STRICT
# 4     STRICT

# %%
#define entities and event mentions to generate two different json files later
events = ["ACTION", "EVENT", "MISC"]

# %%
df_entities = pd.DataFrame(columns = ["coref_chain", "doc_id_full", "doc_id", "pol_direction", "is_continuous", "is_singleton", "mention_id", "mention_type", "mention_full_type", "score", "sent_id", "tokens_number", "tokens_str", "topic_id", "coref_type", "description"])
df_events = pd.DataFrame(columns = ["coref_chain", "doc_id_full", "doc_id", "pol_direction", "is_continuous", "is_singleton", "mention_id", "mention_type", "mention_full_type", "score", "sent_id", "tokens_number", "tokens_str", "topic_id", "coref_type", "description"])

for i, row in df_final.iterrows():
    if row["mention_type"] not in events:
        df_entities = df_entities.append(row)
    else:
        df_events = df_events.append(row)

# %%
with open(f'./entity_mentions.json', 'w', encoding='utf-8') as f:
    f.write(ujson.dumps(df_entities.to_dict('index'), indent=4, ensure_ascii=False, escape_forward_slashes=False))

with open(f'./event_mentions.json', 'w', encoding='utf-8') as f:
    f.write(ujson.dumps(df_events.to_dict('index'), indent=4, ensure_ascii=False, escape_forward_slashes=False))

# %%
#also make a all_mentions csv file
df_all_mentions = df_final.drop(columns=["is_continuous", "is_singleton", "score", "sent_id", "tokens_number", "topic_id", "coref_type"]).rename(index = df_final.mention_id)
df_all_mentions = df_all_mentions.drop(columns = ["mention_id"])
df_all_mentions.to_csv(path_or_buf="all_mentions.csv", sep=",", na_rep="")

# %%
df_all_mentions.head(30)
# Out:
#               coref_chain                description doc_id_full  doc_id  \
# 0_L_0_1_6    COUNTRY00002                        USA       0_L_0       0
# 0_L_0_1_14   COUNTRY00003                        PRK       0_L_0       0
# 0_L_0_1_9    COUNTRY00004                        USA       0_L_0       0
# 0_L_0_1_35     EVENT00005             PRK USA Summit       0_L_0       0
# 0_L_0_1_19    ACTION00006                Trip to PRK       0_L_0       0
# 0_L_0_1_35    ACTION00007                Trip to PRK       0_L_0       0
# 0_L_0_2_80   COUNTRY00008                        PRK       0_L_0       0
# 0_L_0_2_72   COUNTRY00009                        USA       0_L_0       0
# 0_L_0_2_91   COUNTRY00010                        USA       0_L_0       0
# 0_L_0_2_100    EVENT00011             PRK USA Summit       0_L_0       0
# 0_L_0_2_104    EVENT00012             PRK USA Summit       0_L_0       0
# 0_L_0_3_124  COUNTRY00013                        PRK       0_L_0       0
# 0_L_0_3_110  COUNTRY00014                        USA       0_L_0       0
# 0_L_0_4_161  COUNTRY00015                        PRK       0_L_0       0
# 0_L_0_4_170  COUNTRY00016                        USA       0_L_0       0
# 0_L_0_4_171  COUNTRY00017                        PRK       0_L_0       0
# 0_L_0_4_174  COUNTRY00018                        PRK       0_L_0       0
# 0_L_0_5_200  COUNTRY00019                        PRK       0_L_0       0
# 0_L_0_5_211  COUNTRY00020                        USA       0_L_0       0
# 0_L_0_5_200  COUNTRY00021                        KOR       0_L_0       0
# 0_L_0_6_236  COUNTRY00022                        PRK       0_L_0       0
# 0_L_0_6_236  COUNTRY00023                        KOR       0_L_0       0
# 0_L_0_6_241    EVENT00024            PRK KOR Meeting       0_L_0       0
# 0_L_0_6_263   ACTION00025  Negotiate about the peace       0_L_0       0
# 0_L_0_6_263   ACTION00026  Negotiate about the peace       0_L_0       0
# 0_L_0_7_293  COUNTRY00027                        JPN       0_L_0       0
# 0_L_0_7_309    EVENT00028            PRK KOR Meeting       0_L_0       0
# 0_L_0_7_315    EVENT00029             PRK USA Summit       0_L_0       0
# 0_L_0_8_342  COUNTRY00030                        PRK       0_L_0       0
# 0_L_0_8_364    EVENT00031             PRK USA Summit       0_L_0       0
#
#             pol_direction mention_type mention_full_type  \
# 0_L_0_1_6               L      COUNTRY           COUNTRY
# 0_L_0_1_14              L      COUNTRY           COUNTRY
# 0_L_0_1_9               L      COUNTRY           COUNTRY
# 0_L_0_1_35              L        EVENT             EVENT
# 0_L_0_1_19              L       ACTION            ACTION
# 0_L_0_1_35              L       ACTION            ACTION
# 0_L_0_2_80              L      COUNTRY           COUNTRY
# 0_L_0_2_72              L      COUNTRY           COUNTRY
# 0_L_0_2_91              L      COUNTRY           COUNTRY
# 0_L_0_2_100             L        EVENT             EVENT
# 0_L_0_2_104             L        EVENT             EVENT
# 0_L_0_3_124             L      COUNTRY           COUNTRY
# 0_L_0_3_110             L      COUNTRY           COUNTRY
# 0_L_0_4_161             L      COUNTRY           COUNTRY
# 0_L_0_4_170             L      COUNTRY           COUNTRY
# 0_L_0_4_171             L      COUNTRY           COUNTRY
# 0_L_0_4_174             L      COUNTRY           COUNTRY
# 0_L_0_5_200             L      COUNTRY           COUNTRY
# 0_L_0_5_211             L      COUNTRY           COUNTRY
# 0_L_0_5_200             L      COUNTRY           COUNTRY
# 0_L_0_6_236             L      COUNTRY           COUNTRY
# 0_L_0_6_236             L      COUNTRY           COUNTRY
# 0_L_0_6_241             L        EVENT             EVENT
# 0_L_0_6_263             L       ACTION            ACTION
# 0_L_0_6_263             L       ACTION            ACTION
# 0_L_0_7_293             L      COUNTRY           COUNTRY
# 0_L_0_7_309             L        EVENT             EVENT
# 0_L_0_7_315             L        EVENT             EVENT
# 0_L_0_8_342             L      COUNTRY           COUNTRY
# 0_L_0_8_364             L        EVENT             EVENT
#
#                                                     tokens_str
# 0_L_0_1_6                                      C.I.A. director
# 0_L_0_1_14                                         North Korea
# 0_L_0_1_9                                               C.I.A.
# 0_L_0_1_35                                      summit meeting
# 0_L_0_1_19                             to meet with its leader
# 0_L_0_1_35          to lay the groundwork for a summit meeting
# 0_L_0_2_80                                         North Korea
# 0_L_0_2_72                                       United States
# 0_L_0_2_91                                         White House
# 0_L_0_2_100                                  potential meeting
# 0_L_0_2_104             a potential meeting of the two leaders
# 0_L_0_3_124                                        North Korea
# 0_L_0_3_110                                        White House
# 0_L_0_4_161                       North Korean representatives
# 0_L_0_4_170                                             C.I.A.
# 0_L_0_4_171                           North Korean counterpart
# 0_L_0_4_174                      Reconnaissance General Bureau
# 0_L_0_5_200                                           Suh Hoon
# 0_L_0_5_211                                 American officials
# 0_L_0_5_200                                        South Korea
# 0_L_0_6_236                              North and South Korea
# 0_L_0_6_236                                        South Korea
# 0_L_0_6_241                the leaders of those countries meet
# 0_L_0_6_263                 opening the door to a peace treaty
# 0_L_0_6_263                                       peace treaty
# 0_L_0_7_293                                              Japan
# 0_L_0_7_309  a diplomatic thaw underway on the Korean Penin...
# 0_L_0_7_315                       a once-unthinkable encounter
# 0_L_0_8_342                                        North Korea
# 0_L_0_8_364                                  potential meeting

# %%
import numpy as np

# %%
df_final.head(300000)
# Out:
#       coref_chain      description doc_id_full  doc_id pol_direction  \
# 0    COUNTRY00002              USA       0_L_0       0             L
# 1    COUNTRY00003              PRK       0_L_0       0             L
# 2    COUNTRY00004              USA       0_L_0       0             L
# 3      EVENT00005   PRK USA Summit       0_L_0       0             L
# 4     ACTION00006      Trip to PRK       0_L_0       0             L
# ..            ...              ...         ...     ...           ...
# 730   OBJECT00732  KOR PRK hotline      2_L_10       2             L
# 731  COUNTRY00733              KOR      2_L_10       2             L
# 732  COUNTRY00734              PRK      2_L_10       2             L
# 733  COUNTRY00735              KOR      2_L_10       2             L
# 734  COUNTRY00736              USA      2_L_10       2             L
#
#      is_continuous  is_singleton      mention_id mention_type  \
# 0             True          True       0_L_0_1_6      COUNTRY
# 1             True          True      0_L_0_1_14      COUNTRY
# 2             True         False       0_L_0_1_9      COUNTRY
# 3             True         False      0_L_0_1_35        EVENT
# 4             True          True      0_L_0_1_19       ACTION
# ..             ...           ...             ...          ...
# 730           True         False  2_L_10_50_1461       OBJECT
# 731           True          True  2_L_10_50_1465      COUNTRY
# 732           True          True  2_L_10_50_1465      COUNTRY
# 733           True         False  2_L_10_51_1486      COUNTRY
# 734           True          True  2_L_10_53_1517      COUNTRY
#
#     mention_full_type  score  sent_id                tokens_number  \
# 0             COUNTRY     -1        1                       [4, 5]
# 1             COUNTRY     -1        1                      [9, 10]
# 2             COUNTRY     -1        1                          [4]
# 3               EVENT     -1        1                     [31, 32]
# 4              ACTION     -1        1         [11, 12, 13, 14, 15]
# ..                ...    ...      ...                          ...
# 730            OBJECT     -1       50                       [1, 2]
# 731           COUNTRY     -1       50  [5, 6, 7, 8, 9, 10, 11, 12]
# 732           COUNTRY     -1       50              [9, 10, 11, 12]
# 733           COUNTRY     -1       51                       [8, 9]
# 734           COUNTRY     -1       53                          [5]
#
#                                    tokens_str topic_id coref_type
# 0                             C.I.A. director        0     STRICT
# 1                                 North Korea        0     STRICT
# 2                                      C.I.A.        0     STRICT
# 3                              summit meeting        0     STRICT
# 4                     to meet with its leader        0     STRICT
# ..                                        ...      ...        ...
# 730                                  the line        2     STRICT
# 731  a South Korean and a North Korean caller        2     STRICT
# 732                     a North Korean caller        2     STRICT
# 733                                  Mr. Youn        2     STRICT
# 734                                Washington        2     STRICT
#
# [735 rows x 16 columns]

# %%
#generate conll file

df_conll = pd.DataFrame(columns = {"doc_identifier", "sent_id", "token_id", "text", "reference"})

for i, row in tqdm(df.iterrows()):
    for sentence_id, sentence in enumerate(row["doc"].sents):
        for token_id, token in enumerate(sentence):
            doc_id_full = row["source_domain"]
            doc_unique_id = doc_id_full+"_"+str(i)

            df_conll = df_conll.append( {"doc_identifier": doc_unique_id, "sent_id": sentence_id, "token_id": token_id, "text": token.text, "reference": ""}, ignore_index=True)
    if i>=10:
        break
# Out:
# 10it [00:36,  3.66s/it]

# %%
added_corefs = []

print("Processing " + str(len(df_conll)) + " df_conll rows...")

for i, row_conll in tqdm(df_conll.iterrows()):
    amount_of_added_mentions = 0
    for j, row_final in df_final.iterrows():
        tokens_number = row_final["tokens_number"]
        token_id = row_conll["token_id"]
        sent_id = row_conll["sent_id"]
        
        if row_conll["doc_identifier"] == row_final["doc_id_full"] and row_final["sent_id"] == sent_id and token_id in tokens_number:
            added_corefs.append(row_final["coref_chain"])
            coref_chain = row_final["coref_chain"]
            
            #determine the amount of already added corefs with the id (to get the brackets correct)
            coref_count = 0
            for coref in added_corefs:
                if coref == coref_chain: 
                    coref_count = coref_count + 1

            #add a string based on how many or if all corefs have been added
            if coref_count == 1 and len(tokens_number) == 1:    #first and only coref token
                df_conll.at[i, "reference"] = row_conll["reference"] + "| (" + row_final["coref_chain"] + ")"
            elif coref_count == 1:    #first of multiple coref token
                df_conll.at[i, "reference"] = row_conll["reference"] + "| (" + row_final["coref_chain"]
            elif coref_count == len(tokens_number):   #last coref token
                df_conll.at[i, "reference"] = row_conll["reference"] + "| " + row_final["coref_chain"] + ")"
            else: #middle coref tokens
                df_conll.at[i, "reference"] = row_conll["reference"] + "| " + row_final["coref_chain"]
            print(row_conll["reference"])
    
    if row_conll["reference"] != "":
        if row_conll["reference"][0] == "|":    #remove first | from string
            df_conll.at[i, "reference"] = row_conll["reference"][2:]
    if i>1000:
        break
# Out:
# Processing 11104 df_conll rows...
# 12it [00:00, 14.93it/s]
# | (COUNTRY00002
# | (COUNTRY00002| (COUNTRY00004)
# | COUNTRY00002)
# 18it [00:01, 14.75it/s]
# | (COUNTRY00003
# | COUNTRY00003)
# | (ACTION00006
# 20it [00:01, 14.30it/s]
# | ACTION00006
# | ACTION00006
# | ACTION00006
# 34it [00:02, 14.56it/s]
# | ACTION00006)
# | (ACTION00007
# | ACTION00007
# | ACTION00007
# | ACTION00007
# 38it [00:02, 14.81it/s]
# | ACTION00007
# | ACTION00007
# | (EVENT00005
# | (EVENT00005| ACTION00007
# 40it [00:02, 14.47it/s]
# | EVENT00005)
# | EVENT00005)| ACTION00007)
# 76it [00:05, 14.99it/s]
# | (COUNTRY00009
# | COUNTRY00009)
# 84it [00:05, 14.83it/s]
# | (COUNTRY00008
# | COUNTRY00008)
# 96it [00:06, 14.95it/s]
# | (COUNTRY00010
# | COUNTRY00010)
# 102it [00:06, 15.41it/s]
# | (EVENT00012
# | (EVENT00011
# | (EVENT00011| EVENT00012
# | EVENT00011)
# | EVENT00011)| EVENT00012
# 106it [00:07, 14.18it/s]
# | EVENT00012
# | EVENT00012
# | EVENT00012
# | EVENT00012)
# 114it [00:07, 13.95it/s]
# | (COUNTRY00014
# | COUNTRY00014)
# 128it [00:08, 15.93it/s]
# | (COUNTRY00013
# | COUNTRY00013)
# 166it [00:11, 16.06it/s]
# | (COUNTRY00015
# | COUNTRY00015
# | COUNTRY00015)
# 174it [00:11, 16.00it/s]
# | (COUNTRY00016)
# | (COUNTRY00017
# 178it [00:12, 15.98it/s]
# | COUNTRY00017
# | COUNTRY00017)
# 182it [00:12, 15.86it/s]
# | (COUNTRY00018
# | COUNTRY00018
# | COUNTRY00018)
# 202it [00:13, 16.67it/s]
# | (COUNTRY00021
# | COUNTRY00021)
# 210it [00:13, 16.92it/s]
# | (COUNTRY00019
# | COUNTRY00019)
# 214it [00:14, 16.23it/s]
# | (COUNTRY00020
# | COUNTRY00020)
# 240it [00:15, 16.14it/s]
# | (COUNTRY00022
# | COUNTRY00022
# | COUNTRY00022
# | COUNTRY00022| (COUNTRY00023
# | COUNTRY00022)
# | COUNTRY00022)| COUNTRY00023)
# 254it [00:16, 16.92it/s]
# | (EVENT00024
# | EVENT00024
# | EVENT00024
# | EVENT00024
# 258it [00:16, 16.77it/s]
# | EVENT00024
# | EVENT00024)
# 262it [00:17, 16.52it/s]
# | (ACTION00025
# | ACTION00025
# | ACTION00025
# | ACTION00025
# 268it [00:17, 16.43it/s]
# | ACTION00025
# | ACTION00025
# | ACTION00025| (ACTION00026
# | ACTION00025)
# | ACTION00025)| ACTION00026)
# 296it [00:19, 17.26it/s]
# | (COUNTRY00027)
# 308it [00:19, 15.79it/s]
# | (EVENT00028
# | EVENT00028
# | EVENT00028
# | EVENT00028
# 312it [00:20, 16.09it/s]
# | EVENT00028
# | EVENT00028
# | EVENT00028
# | EVENT00028)
# 318it [00:20, 16.29it/s]
# | (EVENT00029
# | EVENT00029
# | EVENT00029
# | EVENT00029
# 322it [00:20, 16.27it/s]
# | EVENT00029)
# 342it [00:21, 17.69it/s]
# | (ACTION00032
# | ACTION00032
# | ACTION00032
# | (COUNTRY00030
# | (COUNTRY00030| ACTION00032
# 346it [00:22, 17.06it/s]
# | COUNTRY00030)
# | COUNTRY00030)| ACTION00032)
# 370it [00:23, 14.80it/s]
# | (EVENT00031
# | EVENT00031)
# 400it [00:25, 16.37it/s]
# | (EVENT00036
# | EVENT00036
# | EVENT00036| (ACTION00037
# | EVENT00036)
# | EVENT00036)| ACTION00037)
# 404it [00:25, 15.18it/s]
# | (COUNTRY00033
# | COUNTRY00033)
# 414it [00:26, 12.24it/s]
# | (COUNTRY00034
# | COUNTRY00034)
# 420it [00:27, 15.12it/s]
# | (COUNTRY00035
# | COUNTRY00035)
# 442it [00:28, 17.41it/s]
# | (EVENT00038
# | EVENT00038
# | EVENT00038
# | EVENT00038
# | EVENT00038)
# 456it [00:29, 18.14it/s]
# | (COUNTRY00039
# | COUNTRY00039)
# 529it [00:33, 16.19it/s]
# | (COUNTRY00040
# | (COUNTRY00040| (COUNTRY00041
# | COUNTRY00040)
# | COUNTRY00040)| COUNTRY00041
# | COUNTRY00041
# | COUNTRY00041
# 533it [00:33, 16.98it/s]
# | COUNTRY00041)
# | (ACTION00042
# | ACTION00042
# | ACTION00042
# 537it [00:33, 17.02it/s]
# | ACTION00042
# | ACTION00042
# | ACTION00042)
# 583it [00:36, 17.50it/s]
# | (EVENT00045
# | (EVENT00043
# | (EVENT00043| EVENT00045
# | EVENT00043)
# | EVENT00043)| EVENT00045
# | EVENT00045
# 587it [00:36, 17.47it/s]
# | EVENT00045
# | EVENT00045
# | EVENT00045
# | EVENT00045
# 591it [00:37, 17.02it/s]
# | EVENT00045
# | EVENT00045
# | EVENT00045
# | EVENT00045
# | EVENT00045
# 595it [00:37, 17.10it/s]
# | EVENT00045
# | (COUNTRY00044
# | (COUNTRY00044| EVENT00045
# | COUNTRY00044)
# | COUNTRY00044)| EVENT00045)
# 601it [00:37, 17.56it/s]
# | (ACTION00046
# | ACTION00046
# | ACTION00046
# | ACTION00046
# 605it [00:37, 17.38it/s]
# | ACTION00046)
# 623it [00:38, 18.75it/s]
# | (COUNTRY00048
# | COUNTRY00048
# | COUNTRY00048
# | COUNTRY00048)
# 663it [00:41, 18.35it/s]
# | (COUNTRY00047
# | COUNTRY00047)
# 675it [00:41, 17.59it/s]
# | (COUNTRY00050
# | COUNTRY00050)
# | (ACTION00051
# | ACTION00051
# 680it [00:42, 18.33it/s]
# | ACTION00051
# | ACTION00051
# | ACTION00051
# | ACTION00051)
# 686it [00:42, 18.44it/s]
# | (COUNTRY00049
# | COUNTRY00049)
# | (MISC00052
# 690it [00:42, 17.84it/s]
# | MISC00052
# | MISC00052
# | MISC00052)
# 702it [00:43, 18.65it/s]
# | (ACTION00053
# | ACTION00053)
# 724it [00:44, 18.65it/s]
# | (ACTION00054
# | ACTION00054
# | ACTION00054
# | ACTION00054
# | ACTION00054
# 728it [00:44, 18.25it/s]
# | ACTION00054
# | ACTION00054)
# 758it [00:46, 18.86it/s]
# | (ACTION00055
# | ACTION00055
# | ACTION00055
# | ACTION00055
# 760it [00:46, 18.56it/s]
# | ACTION00055
# | ACTION00055)
# 794it [00:48, 18.24it/s]
# | (COUNTRY00056
# | COUNTRY00056)
# 829it [00:50, 19.03it/s]
# | (EVENT00058
# | EVENT00058
# | EVENT00058
# | EVENT00058
# | EVENT00058
# 833it [00:50, 18.05it/s]
# | EVENT00058
# | EVENT00058
# | (COUNTRY00057
# | (COUNTRY00057| EVENT00058
# | COUNTRY00057)
# | COUNTRY00057)| EVENT00058)
# 850it [00:51, 19.13it/s]
# | (EVENT00061
# | EVENT00061
# | EVENT00061
# | EVENT00061
# 852it [00:51, 18.41it/s]
# | EVENT00061)
# | (COUNTRY00059
# 856it [00:51, 17.40it/s]
# | COUNTRY00059)
# | (MISC00062
# | MISC00062
# | MISC00062
# 862it [00:51, 18.18it/s]
# | MISC00062
# | MISC00062
# | MISC00062
# | MISC00062
# | MISC00062
# 866it [00:52, 18.11it/s]
# | MISC00062
# | MISC00062
# | MISC00062)
# 883it [00:53, 18.51it/s]
# | (COUNTRY00060)
# 911it [00:54, 18.17it/s]
# | (COUNTRY00064
# | COUNTRY00064
# | COUNTRY00064
# | COUNTRY00064
# 917it [00:54, 17.26it/s]
# | COUNTRY00064
# | COUNTRY00064
# | COUNTRY00064
# | COUNTRY00064
# 920it [00:55, 18.08it/s]
# | COUNTRY00064
# | COUNTRY00064
# | COUNTRY00064)
# 930it [00:55, 17.15it/s]
# | (COUNTRY00063
# | COUNTRY00063)
# 938it [00:56, 17.76it/s]
# | (COUNTRY00066
# | COUNTRY00066)
# 942it [00:56, 18.20it/s]
# | (ACTION00067
# | ACTION00067)
# | (COUNTRY00065
# | (COUNTRY00065| (COUNTRY00068
# 946it [00:56, 17.97it/s]
# | COUNTRY00065)
# | COUNTRY00065)| COUNTRY00068
# | COUNTRY00068
# | COUNTRY00068
# | COUNTRY00068
# 950it [00:56, 17.40it/s]
# | COUNTRY00068
# | COUNTRY00068
# | COUNTRY00068)
# 965it [00:57, 18.88it/s]
# | (COUNTRY00069)
# 980it [00:58, 19.04it/s]
# | (ACTION00070
# | ACTION00070)
# 982it [00:58, 18.91it/s]
# | (COUNTRY00073)
# 1001it [00:59, 16.78it/s]
# | (COUNTRY00071

# %%
df_conll.head(60)
# Out:
#    sent_id                      reference        text doc_identifier token_id
# 0        0                                       WEST          0_L_0        0
# 1        0                                       PALM          0_L_0        1
# 2        0                                      BEACH          0_L_0        2
# 3        0                                          ,          0_L_0        3
# 4        0                                       Fla.          0_L_0        4
# 5        0                                          —          0_L_0        5
# 6        1                                  President          0_L_0        0
# 7        1                                      Trump          0_L_0        1
# 8        1                                 dispatched          0_L_0        2
# 9        1                                        the          0_L_0        3
# 10       1  (COUNTRY00002| (COUNTRY00004)      C.I.A.          0_L_0        4
# 11       1                  COUNTRY00002)    director          0_L_0        5
# 12       1                                       Mike          0_L_0        6
# 13       1                                     Pompeo          0_L_0        7
# 14       1                                         to          0_L_0        8
# 15       1                  (COUNTRY00003       North          0_L_0        9
# 16       1                  COUNTRY00003)       Korea          0_L_0       10
# 17       1                   (ACTION00006          to          0_L_0       11
# 18       1                    ACTION00006        meet          0_L_0       12
# 19       1                    ACTION00006        with          0_L_0       13
# 20       1                    ACTION00006         its          0_L_0       14
# 21       1                   ACTION00006)      leader          0_L_0       15
# 22       1                                          ,          0_L_0       16
# 23       1                                        Kim          0_L_0       17
# 24       1                                       Jong          0_L_0       18
# 25       1                                          -          0_L_0       19
# 26       1                                         un          0_L_0       20
# 27       1                                          ,          0_L_0       21
# 28       1                                         in          0_L_0       22
# 29       1                                     recent          0_L_0       23
# 30       1                                      weeks          0_L_0       24
# 31       1                   (ACTION00007          to          0_L_0       25
# 32       1                    ACTION00007         lay          0_L_0       26
# 33       1                    ACTION00007         the          0_L_0       27
# 34       1                    ACTION00007  groundwork          0_L_0       28
# 35       1                    ACTION00007         for          0_L_0       29
# 36       1                    ACTION00007           a          0_L_0       30
# 37       1       (EVENT00005| ACTION00007      summit          0_L_0       31
# 38       1      EVENT00005)| ACTION00007)     meeting          0_L_0       32
# 39       1                                    between          0_L_0       33
# 40       1                                        Mr.          0_L_0       34
# 41       1                                        Kim          0_L_0       35
# 42       1                                        and          0_L_0       36
# 43       1                                        Mr.          0_L_0       37
# 44       1                                      Trump          0_L_0       38
# 45       1                                          ,          0_L_0       39
# 46       1                                        two          0_L_0       40
# 47       1                                     people          0_L_0       41
# 48       1                                    briefed          0_L_0       42
# 49       1                                         on          0_L_0       43
# 50       1                                        the          0_L_0       44
# 51       1                                     secret          0_L_0       45
# 52       1                                       trip          0_L_0       46
# 53       1                                       said          0_L_0       47
# 54       1                                         on          0_L_0       48
# 55       1                                    Tuesday          0_L_0       49
# 56       1                                          .          0_L_0       50
# 57       1                                         \n          0_L_0       51
# 58       2                                        Mr.          0_L_0        0
# 59       2                                      Trump          0_L_0        1

# %%
df_conll.reset_index(drop=True,inplace=True)

with open(f'./conll_test.json', 'w', encoding='utf-8') as f:
    f.write(ujson.dumps(df_conll.to_dict('index'), indent=4, ensure_ascii=False, escape_forward_slashes=False))
